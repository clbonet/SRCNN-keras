# %%
from main import *
# Out:
# Using TensorFlow backend.

# %%
model = NN(1)

# %%
model.train()
# Out:
# Train on 14901 samples, validate on 420 samples
# Epoch 1/1
# 14901/14901 [==============================] - 128s 9ms/step - loss: 0.0085 - mean_squared_error: 0.0085 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 00001: val_loss improved from inf to 0.00210, saving model to SRCNN_check.h5

# %%
model.test_img(load_weights=True)

# %%
model.test_img("./Test/Set14/barbara.bmp",load_weights=True)
