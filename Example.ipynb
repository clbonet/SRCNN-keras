# %%
from main import *
# Out:
# Using TensorFlow backend.

# %%
model = NN(200)
# Out:
# WARNING:tensorflow:From /home/clement/anaconda3/envs/tf1-gpu/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
model.train()
# Out:
# WARNING:tensorflow:From /home/clement/anaconda3/envs/tf1-gpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
#
# Epoch 00001: val_loss improved from inf to 0.00261, saving model to SRCNN_check.h5
#
# Epoch 00002: val_loss improved from 0.00261 to 0.00193, saving model to SRCNN_check.h5
#
# Epoch 00003: val_loss improved from 0.00193 to 0.00169, saving model to SRCNN_check.h5
#
# Epoch 00004: val_loss improved from 0.00169 to 0.00160, saving model to SRCNN_check.h5
#
# Epoch 00005: val_loss improved from 0.00160 to 0.00157, saving model to SRCNN_check.h5
#
# Epoch 00006: val_loss improved from 0.00157 to 0.00154, saving model to SRCNN_check.h5
#
# Epoch 00007: val_loss improved from 0.00154 to 0.00152, saving model to SRCNN_check.h5
#
# Epoch 00008: val_loss improved from 0.00152 to 0.00151, saving model to SRCNN_check.h5
#
# ...

# %%
model.test_img()

# %%
model.test_img("./Test/Set14/barbara.bmp")

# %%
model.test_img("./Test/Set14/barbara.bmp",load_weights=True)
